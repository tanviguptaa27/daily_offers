# %%
import pandas as pd 
import numpy as np

# %%
import time
from datetime import datetime, date, time, timedelta
import dateutil.relativedelta

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel('daily_offers.xlsx',parse_dates=['item_date'])

# %%
df.head()
# Out:
#                                      id   item_date quantity tons    customer  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139  30156308.0
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839  30202938.0
# 2  E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949  30153963.0
# 3  F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065  30349574.0
# 4  4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262  30211560.0
#
#    country status item type  application  thickness   width  \
# 0     28.0    Won         W         10.0       2.00  1500.0
# 1     25.0    Won         W         41.0       0.80  1210.0
# 2     30.0    Won        WI         28.0       0.38   952.0
# 3     32.0    Won         S         59.0       2.30  1317.0
# 4     28.0    Won         W         10.0       4.00  2000.0
#
#                                material_ref  product_ref  delivery date  \
# ...

# %%
df.drop([52], axis=0, inplace=True)

# %%
df1=df.dropna( axis=0, how='any')

# %%
df1['item_date'] = pd.to_datetime(df1['item_date'], format='%Y%m%d',dayfirst=True)

# %%
df1
# Out:
#                                           id  item_date quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE 2021-04-01     54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425 2021-04-01    768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158 2021-04-01    386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50 2021-04-01    202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD 2021-04-01    785.526262
# ...                                      ...        ...           ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76 2020-07-02    102.482422
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB 2020-07-02    208.086469
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320 2020-07-02      4.235594
# 181671  7AFFD323-01D9-4E15-B80D-7D1B03498FC8 2020-07-02         -2000
# 181672  AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC 2020-07-02    406.686538
#
#           customer  country status item type  application  thickness   width  \
# ...

# %%
df1.isnull().sum()
# Out:
# id               0
# item_date        0
# quantity tons    0
# customer         0
# country          0
# status           0
# item type        0
# application      0
# thickness        0
# width            0
# material_ref     0
# product_ref      0
# delivery date    0
# selling_price    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103749 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             103749 non-null  object
#  1   item_date      103749 non-null  datetime64[ns]
#  2   quantity tons  103749 non-null  object
#  3   customer       103749 non-null  float64
#  4   country        103749 non-null  float64
#  5   status         103749 non-null  object
#  6   item type      103749 non-null  object
#  7   application    103749 non-null  float64
#  8   thickness      103749 non-null  float64
#  9   width          103749 non-null  float64
#  10  material_ref   103749 non-null  object
#  11  product_ref    103749 non-null  int64
#  12  delivery date  103749 non-null  float64
#  13  selling_price  103749 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(5)
# memory usage: 11.9+ MB

# %%
df.describe()
# Out:
#           item_date      customer        country    application  \
# count  1.816710e+05  1.816710e+05  181644.000000  181648.000000
# mean   2.020459e+07  3.051221e+07      44.892845      25.615928
# std    4.511765e+03  2.433388e+07      24.404165      17.754151
# min    2.019192e+07  1.245800e+04      25.000000       2.000000
# 25%    2.020093e+07  3.019688e+07      26.000000      10.000000
# 50%    2.020113e+07  3.020524e+07      30.000000      15.000000
# 75%    2.021020e+07  3.028042e+07      78.000000      41.000000
# max    2.021040e+07  2.147484e+09     113.000000      99.000000
#
#            thickness          width   product_ref  delivery date  \
# count  181671.000000  181672.000000  1.816720e+05   1.816710e+05
# mean        2.564836    1295.286698  4.739696e+08   2.020738e+07
# std         6.572338     261.632474  7.175117e+08   2.411065e+04
# min         0.180000       1.000000  6.117280e+05   2.019040e+07
# ...

# %%
df.head()
# Out:
#                                      id   item_date quantity tons    customer  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139  30156308.0
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839  30202938.0
# 2  E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949  30153963.0
# 3  F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065  30349574.0
# 4  4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262  30211560.0
#
#    country status item type  application  thickness   width  \
# 0     28.0    Won         W         10.0       2.00  1500.0
# 1     25.0    Won         W         41.0       0.80  1210.0
# 2     30.0    Won        WI         28.0       0.38   952.0
# 3     32.0    Won         S         59.0       2.30  1317.0
# 4     28.0    Won         W         10.0       4.00  2000.0
#
#                                material_ref  product_ref  delivery date  \
# ...

# %%
df3.head()

# %%
df3['product_ref'].hist()

# %%
df3['customer'].hist()

# %%
df3.hist(column='item_date',by='status',layout=(12,16),figsize=(300,300),sharex=True)

# %%
X = df1["delivery_date"]
Y = df1["selling_price"]
plt.scatter(X, Y)
plt.title("Scatter Plot")
plt.xlabel("delivery_date")
plt.ylabel("selling_price")
plt.show()

# %%
df1['quantity tons'] = df1['quantity tons'].astype(float)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103749 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             103749 non-null  object
#  1   item_date      103749 non-null  datetime64[ns]
#  2   quantity tons  103749 non-null  float64
#  3   customer       103749 non-null  float64
#  4   country        103749 non-null  float64
#  5   status         103749 non-null  object
#  6   item type      103749 non-null  object
#  7   application    103749 non-null  float64
#  8   thickness      103749 non-null  float64
#  9   width          103749 non-null  float64
#  10  material_ref   103749 non-null  object
#  11  product_ref    103749 non-null  int64
#  12  delivery date  103749 non-null  float64
#  13  selling_price  103749 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(1), object(4)
# memory usage: 11.9+ MB

# %%
df1['customer'] = df1['customer'].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103749 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             103749 non-null  object
#  1   item_date      103749 non-null  datetime64[ns]
#  2   quantity tons  103749 non-null  float64
#  3   customer       103749 non-null  int32
#  4   country        103749 non-null  float64
#  5   status         103749 non-null  object
#  6   item type      103749 non-null  object
#  7   application    103749 non-null  float64
#  8   thickness      103749 non-null  float64
#  9   width          103749 non-null  float64
#  10  material_ref   103749 non-null  object
#  11  product_ref    103749 non-null  int64
#  12  delivery date  103749 non-null  float64
#  13  selling_price  103749 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int32(1), int64(1), object(4)
# memory usage: 11.5+ MB

# %%
df1.head(60)
# Out:
#                                       id  item_date  quantity tons  customer  \
# 0   EC06F063-9DF0-440C-8764-0B0C05A4F6AE 2021-04-01      54.151139  30156308
# 1   4E5F4B3D-DDDF-499D-AFDE-A3227EC49425 2021-04-01     768.024839  30202938
# 2   E140FF1B-2407-4C02-A0DD-780A093B1158 2021-04-01     386.127949  30153963
# 3   F8D507A0-9C62-4EFE-831E-33E1DA53BB50 2021-04-01     202.411065  30349574
# 4   4E1C4E78-152B-430A-8094-ADD889C9D0AD 2021-04-01     785.526262  30211560
# 5   FE372230-29B1-4A29-BB73-CB9D3078C286 2021-04-01     225.790676  30202938
# 6   E1B47219-42C8-411D-AE46-AD5256DC4757 2021-04-01       3.522613  30209509
# 7   AA3F18A2-A7D6-43DE-8644-F0632AE2CB68 2021-04-01     113.387124  30342192
# 8   2851F48B-DA32-4DF3-884B-17A3100DD65A 2021-04-01      69.071853  30341428
# 9   6E4D638C-A820-4A40-836F-C9D48BC65528 2021-04-01     630.626917  30202938
# 10  B85870F5-E1C7-4CAA-A7DA-355DC192B11D 2021-04-01       9.175770  30209509
# ...

# %%
df1['country'] = df1['country'].astype(int)

# %%
df1.head(20)
# Out:
#                                       id  item_date  quantity tons  customer  \
# 0   EC06F063-9DF0-440C-8764-0B0C05A4F6AE 2021-04-01      54.151139  30156308
# 1   4E5F4B3D-DDDF-499D-AFDE-A3227EC49425 2021-04-01     768.024839  30202938
# 2   E140FF1B-2407-4C02-A0DD-780A093B1158 2021-04-01     386.127949  30153963
# 3   F8D507A0-9C62-4EFE-831E-33E1DA53BB50 2021-04-01     202.411065  30349574
# 4   4E1C4E78-152B-430A-8094-ADD889C9D0AD 2021-04-01     785.526262  30211560
# 5   FE372230-29B1-4A29-BB73-CB9D3078C286 2021-04-01     225.790676  30202938
# 6   E1B47219-42C8-411D-AE46-AD5256DC4757 2021-04-01       3.522613  30209509
# 7   AA3F18A2-A7D6-43DE-8644-F0632AE2CB68 2021-04-01     113.387124  30342192
# 8   2851F48B-DA32-4DF3-884B-17A3100DD65A 2021-04-01      69.071853  30341428
# 9   6E4D638C-A820-4A40-836F-C9D48BC65528 2021-04-01     630.626917  30202938
# 10  B85870F5-E1C7-4CAA-A7DA-355DC192B11D 2021-04-01       9.175770  30209509
# ...

# %%
df1['status'].value_counts()
# Out:
# Won                74727
# Lost               12920
# Not lost for AM     9847
# To be approved      2480
# Revised             2038
# Draft               1708
# Offered               26
# Offerable              3
# Name: status, dtype: int64

# %%
df1['item_date'].value_counts()
# Out:
# 2020-12-02    1720
# 2021-03-04    1567
# 2020-09-29    1346
# 2020-12-16    1294
# 2020-11-24    1196
#               ...
# 2021-02-27       1
# 2020-08-01       1
# 2020-09-06       1
# 2020-12-06       1
# 2020-08-29       1
# Name: item_date, Length: 234, dtype: int64

# %%
df1['application'] = df1['application'].astype(int)

# %%
df1['width'] = df1['width'].astype(int)

# %%
df1['delivery date'] = df1['delivery date'].astype(int)

# %%
df1['material_ref'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                                      DEQ1 S460MC
# 1         0000000000000000000000000000000000104991
# 2                                         S0380700
# 3                          DX51D+ZM310MAO 2.3X1317
# 4                                  2_S275JR+AR-CL1
#                             ...
# 181668    0000000000000000000000000000000001000777
# 181669    0000000000000000000000000000000001000227
# 181670    0000000000000000000000000000000001004216
# 181671    0000000000000000000000000000000001001149
# 181672    0000000000000000000000000000000001005439
# Name: material_ref, Length: 103749, dtype: object>

# %%
df1.drop(['material_ref'], axis=1)
# Out:
#                                           id  item_date  quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE 2021-04-01      54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425 2021-04-01     768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158 2021-04-01     386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50 2021-04-01     202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD 2021-04-01     785.526262
# ...                                      ...        ...            ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76 2020-07-02     102.482422
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB 2020-07-02     208.086469
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320 2020-07-02       4.235594
# 181671  7AFFD323-01D9-4E15-B80D-7D1B03498FC8 2020-07-02   -2000.000000
# 181672  AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC 2020-07-02     406.686538
#
#         customer  country status item type  application  thickness  width  \
# ...

# %%
df1.rename(columns={"item type": "item_type"},inplace=True)

# %%
df1.rename(columns={"delivery date": "delivery_date"},inplace=True)

# %%
df1.rename(columns={"quantity tons": "quantity_tons"},inplace=True)

# %%
df1['delivery_date'] = pd.to_datetime(df1['delivery_date'], format='%Y%m%d',dayfirst=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103749 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             103749 non-null  object
#  1   item_date      103749 non-null  datetime64[ns]
#  2   quantity_tons  103749 non-null  float64
#  3   customer       103749 non-null  int32
#  4   country        103749 non-null  int32
#  5   status         103749 non-null  object
#  6   item_type      103749 non-null  object
#  7   application    103749 non-null  int32
#  8   thickness      103749 non-null  float64
#  9   width          103749 non-null  int32
#  10  material_ref   103749 non-null  object
#  11  product_ref    103749 non-null  int64
#  12  delivery_date  103749 non-null  datetime64[ns]
#  13  selling_price  103749 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int32(4), int64(1), object(4)
# memory usage: 10.3+ MB

# %%
df1.drop(['material_ref'], axis=1,inplace=True)

# %%
df1.drop(['id'], axis=1,inplace=True)

# %%
df1
# Out:
#         item_date  quantity_tons  customer  country status item_type  \
# 0      2021-04-01      54.151139  30156308       28    Won         W
# 1      2021-04-01     768.024839  30202938       25    Won         W
# 2      2021-04-01     386.127949  30153963       30    Won        WI
# 3      2021-04-01     202.411065  30349574       32    Won         S
# 4      2021-04-01     785.526262  30211560       28    Won         W
# ...           ...            ...       ...      ...    ...       ...
# 181668 2020-07-02     102.482422  30200854       25    Won         W
# 181669 2020-07-02     208.086469  30200854       25    Won         W
# 181670 2020-07-02       4.235594  30200854       25    Won         W
# 181671 2020-07-02   -2000.000000  30200854       25    Won         W
# 181672 2020-07-02     406.686538  30200854       25    Won         W
#
#         application  thickness  width  product_ref delivery_date  \
# 0                10       2.00   1500   1670798778    2021-07-01
# ...

# %%
df1['selling_price'] = df1['selling_price'].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103749 entries, 0 to 181672
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item_date      103749 non-null  datetime64[ns]
#  1   quantity_tons  103749 non-null  float64
#  2   customer       103749 non-null  int32
#  3   country        103749 non-null  int32
#  4   status         103749 non-null  object
#  5   item_type      103749 non-null  object
#  6   application    103749 non-null  int32
#  7   thickness      103749 non-null  float64
#  8   width          103749 non-null  int32
#  9   product_ref    103749 non-null  int64
#  10  delivery_date  103749 non-null  datetime64[ns]
#  11  selling_price  103749 non-null  int32
# dtypes: datetime64[ns](2), float64(2), int32(5), int64(1), object(2)
# memory usage: 8.3+ MB

# %%
df3.describe()
# Out:
#            customer        country    application          width  \
# count  1.037490e+05  103749.000000  103749.000000  103749.000000
# mean   3.022640e+07      44.063731      27.109244    1281.028183
# std    6.730085e+04      24.150337      18.034063     262.630742
# min    3.014762e+07      25.000000       2.000000      20.000000
# 25%    3.016599e+07      26.000000      10.000000    1165.000000
# 50%    3.020292e+07      28.000000      20.000000    1250.000000
# 75%    3.026890e+07      78.000000      41.000000    1500.000000
# max    3.040817e+07     113.000000      99.000000    2990.000000
#
#         product_ref  selling_price   status_Draft    status_Lost  \
# count  1.037490e+05   1.037490e+05  103749.000000  103749.000000
# mean   4.290771e+08   1.773615e+03       0.016463       0.124531
# std    6.943965e+08   3.104625e+05       0.127248       0.330188
# min    6.117280e+05  -1.160000e+03       0.000000       0.000000
# ...

# %%
df1.head()
# Out:
#    item_date  quantity_tons  customer  country status item_type  application  \
# 0 2021-04-01      54.151139  30156308       28    Won         W           10
# 1 2021-04-01     768.024839  30202938       25    Won         W           41
# 2 2021-04-01     386.127949  30153963       30    Won        WI           28
# 3 2021-04-01     202.411065  30349574       32    Won         S           59
# 4 2021-04-01     785.526262  30211560       28    Won         W           10
#
#    thickness  width  product_ref delivery_date  selling_price
# 0       2.00   1500   1670798778    2021-07-01            854
# 1       0.80   1210   1668701718    2021-04-01           1047
# 2       0.38    952       628377    2021-01-01            644
# 3       2.30   1317   1668701718    2021-01-01            768
# 4       4.00   2000       640665    2021-03-01            577

# %%
#featurescaling
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas as pd


# Extract the features to be scaled
X = df3[["customer","product_ref","quantity_tons"]]

# Standardization
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# Normalization
scaler = MinMaxScaler()
X_norm = scaler.fit_transform(X)

# %%
df3.describe()
# Out:
#            customer        country    application          width  \
# count  1.037490e+05  103749.000000  103749.000000  103749.000000
# mean   3.022640e+07      44.063731      27.109244    1281.028183
# std    6.730085e+04      24.150337      18.034063     262.630742
# min    3.014762e+07      25.000000       2.000000      20.000000
# 25%    3.016599e+07      26.000000      10.000000    1165.000000
# 50%    3.020292e+07      28.000000      20.000000    1250.000000
# 75%    3.026890e+07      78.000000      41.000000    1500.000000
# max    3.040817e+07     113.000000      99.000000    2990.000000
#
#         product_ref  selling_price   status_Draft    status_Lost  \
# count  1.037490e+05   1.037490e+05  103749.000000  103749.000000
# mean   4.290771e+08   1.773615e+03       0.016463       0.124531
# std    6.943965e+08   3.104625e+05       0.127248       0.330188
# min    6.117280e+05  -1.160000e+03       0.000000       0.000000
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.compose import ColumnTransformer

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.linear_model import Ridge

# %%
# Add Ridge regularization
ridge = Ridge(alpha=0.1)
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.1)

# %%
df3.head()
# Out:
#    item_date       quantity_tons  customer  country  application thickness  \
# 0 2021-04-01   54.15113861692779  30156308       28           10       2.0
# 1 2021-04-01   768.0248392021871  30202938       25           41       0.8
# 2 2021-04-01   386.1279489091378  30153963       30           28      0.38
# 3 2021-04-01  202.41106540948442  30349574       32           59       2.3
# 4 2021-04-01   785.5262615733325  30211560       28           10       4.0
#
#    width  product_ref delivery_date  selling_price  ...  status_Offered  \
# 0   1500   1670798778    2021-07-01            854  ...               0
# 1   1210   1668701718    2021-04-01           1047  ...               0
# 2    952       628377    2021-01-01            644  ...               0
# 3   1317   1668701718    2021-01-01            768  ...               0
# 4   2000       640665    2021-03-01            577  ...               0
#
#    status_Revised  status_To be approved  status_Won  item_type_IPL  \
# ...

# %%
X=df3.drop(['item_date','delivery_date','selling_price','product_ref'],axis=1)
Y=df3['selling_price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.1,random_state=1)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93374 entries, 164185 to 172004
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer                93374 non-null  int32
#  1   country                 93374 non-null  int32
#  2   application             93374 non-null  int32
#  3   thickness               93374 non-null  object
#  4   width                   93374 non-null  int32
#  5   status_Draft            93374 non-null  uint8
#  6   status_Lost             93374 non-null  uint8
#  7   status_Not lost for AM  93374 non-null  uint8
#  8   status_Offerable        93374 non-null  uint8
#  9   status_Offered          93374 non-null  uint8
#  10  status_Revised          93374 non-null  uint8
#  11  status_To be approved   93374 non-null  uint8
#  12  status_Won              93374 non-null  uint8
#  13  item_type_IPL           93374 non-null  uint8
# ...

# %%
y_train
# Out:
# 164185    503
# 163406    586
# 147556    842
# 29479     857
# 97615     700
#          ...
# 87725     741
# 171077    481
# 9833      831
# 136525    875
# 172004    795
# Name: selling_price, Length: 93374, dtype: int32

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10375 entries, 45706 to 168460
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer                10375 non-null  int32
#  1   country                 10375 non-null  int32
#  2   application             10375 non-null  int32
#  3   thickness               10375 non-null  object
#  4   width                   10375 non-null  int32
#  5   status_Draft            10375 non-null  uint8
#  6   status_Lost             10375 non-null  uint8
#  7   status_Not lost for AM  10375 non-null  uint8
#  8   status_Offerable        10375 non-null  uint8
#  9   status_Offered          10375 non-null  uint8
#  10  status_Revised          10375 non-null  uint8
#  11  status_To be approved   10375 non-null  uint8
#  12  status_Won              10375 non-null  uint8
#  13  item_type_IPL           10375 non-null  uint8
# ...

# %%
y_test
# Out:
# 45706      749
# 50787      725
# 102628     737
# 74462      818
# 134301    1091
#           ...
# 151947     858
# 155568     706
# 78659      982
# 20533      959
# 168460     733
# Name: selling_price, Length: 10375, dtype: int32

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#prediction on traning data prediction
training_data=lr.predict(X_train)

# %%
training_data
# Out:
# array([10263.37789451, 24136.76850815, 10498.51389155, ...,
#         -301.90378902, 10153.80517485, -1486.44529844])

# %%
#R score 
error_score=metrics.r2_score(y_train,training_data)

# %%
error_score
# Out:
# 0.00034198144649000284

# %%
test_data=lr.predict(X_test)

# %%
test_data
# Out:
# array([  634.1661661 , 23963.87082132,   846.35534061, ...,
#         1208.32493038,   102.92619647, 10676.5016945 ])

# %%
error_score1=metrics.r2_score(y_test,test_data)

# %%
error_score1
# Out:
# -673.3361726460014

# %%
from sklearn.linear_model import Lasso
from sklearn import metrics

# %%
#lasso
lasso=Lasso()

# %%
lasso.fit(X_train,y_train)
# Out:
# Lasso()

# %%
training_data1=lasso.predict(X_train)

# %%
training_data1
# Out:
# array([10259.92070697, 24113.47954212, 10495.05284241, ...,
#         -296.65902815, 10147.22894565, -1475.37598628])

# %%
#R score 
error_score=metrics.r2_score(y_train,training_data1)

# %%
error_score
# Out:
# 0.0003419865663916166

# %%
test_data1=lasso.predict(X_test)

# %%
error_scoree=metrics.r2_score(y_test,test_data1)

# %%
error_scoree
# Out:
# -671.8981428858463

# %%
import re

input_string = 'Not lost for AM'

if re.match(r'^-?\d+(?:\.\d+)?$', input_string):
    float_value = float(input_string)
else:
    # handle the error, such as setting the value to zero
    float_value = 0.0

# %%
try:
    float_value = float('Not lost for AM' )
except ValueError:
    # handle the error, such as setting the value to zero
    float_value = 0.0

# %%
input_string = "Not lost for AM"
try:
    float_value = float(input_string)
except ValueError:
    print("Unable to convert input string to float:", input_string)
    float_value = None
# Out:
# Unable to convert input string to float: Not lost for AM

# %%
#ohe=OneHotEncoder(drop='first',sparse=False)
#status_item=ohe.fit_transform(X_train[['status','item_type']])

# %%
#status_item=ohe.fit_transform(X_test[['status','item_type']])

# %%
#df2=pd.DataFrame(status_item)

# %%
df3 = pd.concat([df1, pd.get_dummies(df1[["status","item_type"]])], axis=1)

# %%
df3.isnull().sum()
# Out:
# item_date                 0
# quantity_tons             0
# customer                  0
# country                   0
# status                    0
# item_type                 0
# application               0
# thickness                 0
# width                     0
# product_ref               0
# delivery_date             0
# selling_price             0
# status_Draft              0
# status_Lost               0
# status_Not lost for AM    0
# status_Offerable          0
# status_Offered            0
# status_Revised            0
# status_To be approved     0
# status_Won                0
# item_type_IPL             0
# item_type_Others          0
# item_type_PL              0
# item_type_S               0
# item_type_W               0
# item_type_WI              0
# dtype: int64

# %%
df3.tail(60)
# Out:
#         item_date  quantity_tons  customer  country           status  \
# 181560 2020-07-02       6.133762  30200854       25              Won
# 181561 2020-07-02      19.055390  30201866       32              Won
# 181562 2020-07-02       8.056298  30200854       25              Won
# 181563 2020-07-02      10.125819  30201866       32              Won
# 181564 2020-07-02       8.245869  30200854       25              Won
# 181565 2020-07-02      17.254009  30201866       32              Won
# 181566 2020-07-02       8.020610  30200854       25              Won
# 181567 2020-07-02      10.980398  30201866       32              Won
# 181568 2020-07-02       5.862336  30200854       25              Won
# 181569 2020-07-02      14.247148  30201866       32              Won
# 181570 2020-07-02      23.883504  30200854       25              Won
# 181571 2020-07-02      17.748421  30201866       32              Won
# 181572 2020-07-02       7.445263  30200854       25              Won
# ...

# %%
df1.isnull().sum()
# Out:
# item_date        0
# quantity_tons    0
# customer         0
# country          0
# status           0
# item_type        0
# application      0
# thickness        0
# width            0
# product_ref      0
# delivery_date    0
# selling_price    0
# dtype: int64

# %%
df3['status'].value_counts()
# Out:
# Won                74727
# Lost               12920
# Not lost for AM     9847
# To be approved      2480
# Revised             2038
# Draft               1708
# Offered               26
# Offerable              3
# Name: status, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

from sklearn import metrics

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103749 entries, 0 to 181672
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   item_date               103749 non-null  datetime64[ns]
#  1   quantity_tons           103749 non-null  float64
#  2   customer                103749 non-null  int32
#  3   country                 103749 non-null  int32
#  4   status                  103749 non-null  object
#  5   item_type               103749 non-null  object
#  6   application             103749 non-null  int32
#  7   thickness               103749 non-null  float64
#  8   width                   103749 non-null  int32
#  9   product_ref             103749 non-null  int64
#  10  delivery_date           103749 non-null  datetime64[ns]
#  11  selling_price           103749 non-null  int32
#  12  status_Draft            103749 non-null  uint8
# ...

# %%
df3['thickness']=df3['thickness'].astype(str)

# %%
df3['quantity_tons']=df3['quantity_tons'].astype(str)

# %%
df3.rename({'quantity tons': 'quantity_tons'}, axis=1, inplace=True)

# %%
df3.head(60)

# %%
df3['delivery_date'] = pd.to_datetime(df3['delivery_date']).dt.date

# %%
df3['item_date'] = pd.to_datetime(df3['item_date']).dt.date

# %%
df3['delivery_date'] = pd.to_datetime(df3['delivery_date'])

# %%
df3['item_date'] = pd.to_datetime(df3['item_date'])

# %%
df3.info()

# %%
df3.head()

# %%
df3.info()
